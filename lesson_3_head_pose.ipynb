# %% [markdown]
# <a href="https://colab.research.google.com/github/sunilhucharaddi/fastai-v3/blob/master/lesson_3_head_pose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'fastai-v3/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Regression with BIWI head pose dataset**

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *

# %% [markdown]
# **Getting and converting data**

# %%
path = untar_data(URLs.BIWI_HEAD_POSE)

# %%
cal = np.genfromtxt(path/'01'/'rgb.cal', skip_footer=6);cal
# Out:
# array([[517.679,   0.   , 320.   ],
#        [  0.   , 517.679, 240.5  ],
#        [  0.   ,   0.   ,   1.   ]])

# %%
fname = '09/frame_00667_rgb.jpg'

# %%
def img2txt_name(f): return path/f'{str(f)[:-7]}pose.txt'

# %%
img = open_image(path/fname)
img.show()

# %%
ctr = np.genfromtxt(img2txt_name(fname), skip_header=3);ctr
# Out:
# array([187.332 ,  40.3892, 893.135 ])

# %%
def convert_biwi(coords):
    c1 = coords[0] * cal[0][0]/coords[2] + cal[0][2]
    c2 = coords[1] * cal[1][1]/coords[2] + cal[1][2]
    return tensor([c2,c1])

def get_ctr(f):
    ctr = np.genfromtxt(img2txt_name(f), skip_header=3)
    return convert_biwi(ctr)

def get_ip(img,pts): return ImagePoints(FlowField(img.size, pts), scale=True)

# %%
get_ctr(fname)
# Out:
# tensor([263.9104, 428.5814])

# %%
ctr = get_ctr(fname)
img.show(y=get_ip(img, ctr), figsize = (6,6))

# %% [markdown]
# **Creating a dataset**

# %%
data = (PointsItemList.from_folder(path)
          .split_by_valid_func(lambda o: o.parent.name=='13')
          .label_from_func(get_ctr)
          .transform(get_transforms(),tfm_y=True, size=(120,160))
          .databunch().normalize(imagenet_stats)
          )

# %%
data.show_batch(3, figsize=(9,6))

# %% [markdown]
# **Train Model**

# %%
learn = cnn_learner(data, models.resnet34)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:01<00:00, 69.7MB/s]

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
# ...

# %%
lr=2e-2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.127122</td>
#       <td>0.012645</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.043476</td>
#       <td>0.002764</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.014887</td>
#       <td>0.005100</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.008554</td>
#       <td>0.003275</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.006420</td>
#       <td>0.003070</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (15193 items)
# x: PointsItemList
# Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160)
# y: PointsLabelList
# ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160)
# Path: /root/.fastai/data/biwi_head_pose;
#
# Valid: LabelList (485 items)
# x: PointsItemList
# Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160),Image (3, 120, 160)
# y: PointsLabelList
# ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160),ImagePoints (120, 160)
# Path: /root/.fastai/data/biwi_head_pose;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
# ...

# %%
learn.show_results()

# %% [markdown]
# **Daat augmentation**

# %%
tfms = get_transforms(max_rotate=20, max_zoom=1.5,max_lighting=0.5,max_warp=0.4,p_affine.,p_lighting=1.)


data = (PointsItemList.from_folder(path)
          .split_by_valid_func(lambda o: o.parent.name=='13')
          .label_from_func(get_ctr)
          .transform(tfms,tfm_y=True,size=(120,160))
          .databunch().normalize(imagenet_stats)
          )
# Out:
#   File "<ipython-input-23-cfcd934965fd>", line 1
#     tfms = get_transforms(max_rotate=20, max_zoom=1.5,max_lighting=0.5,max_warp=0.4,p_affine.,p_lighting=1.)
#                                                                                              ^
# SyntaxError: invalid syntax

# %%
def _plot(i,j,ax):
  x,y = data.train_ds[0]
  x.show(ax, y=y)

plot_multi(_plot,3,3,figsize=(8,6))
